# %%
import pandas as pd

# %%
df = pd.read_csv("2019_CO_NBI.csv")
df_latlong = df[["LAT_016", "LONG_017"]]
df_latlong
# Out:
# C:\Users\tobby\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (71,73,102) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        LAT_016   LONG_017
# 0     38263100  107331900
# 1     38264900  107331900
# 2     38275000  107325900
# 3     39133200  107483900
# 4     39135570  107484979
# ...        ...        ...
# 8780  39453600  102275070
# 8781  39370063  102240303
# 8782  39373609  102240294
# 8783  39341998  102213922
# 8784  39342699  102214036
#
# [8785 rows x 2 columns]

# %%
df['LAT_016']
# Out:
# 0       38263100
# 1       38264900
# 2       38275000
# 3       39133200
# 4       39135570
#           ...
# 8780    39453600
# 8781    39370063
# 8782    39373609
# 8783    39341998
# 8784    39342699
# Name: LAT_016, Length: 8785, dtype: int64

# %%
from geopy.geocoders import Nominatim

# %%
locator = Nominatim(user_agent="myGeocoder")

# %%
def dms2dd(s):

    minutes = s[-6:-4]
    seconds = s[-4:]
    seconds_decimal = s[-4:-2] + "." +s[-2:]

    temp_dms = minutes
    temp_dms = temp_dms + seconds
    
    if temp_dms in s:
        degrees = s.replace(temp_dms,'')
    
    dd = float(degrees) + float(minutes)/60 + float(seconds_decimal)/(60*60);
    
    return dd

# %%
decimal_lats = []
decimal_longs = []

for index, row in df.iterrows():
    str_lat = str(row["LAT_016"])
    str_long = str(row["LONG_017"])
    
    if len(str_lat) < 8 or len(str_long) < 8:
        continue
    
    decimal_lat = dms2dd(str_lat)
    decimal_long = dms2dd(str_long)
    
#     decimal_long = 360 - decimal_long
    
    decimal_lats.append(decimal_lat)
    decimal_longs.append(decimal_long)
    
decimal_lats
decimal_longs

df_new = pd.DataFrame()
df_new['decimal_lats'] = decimal_lats
df_new['decimal_longs'] = decimal_longs

df_new
# Out:
#       decimal_lats  decimal_longs
# 0        38.441944     107.555278
# 1        38.446944     107.555278
# 2        38.463889     107.549722
# 3        39.225556     107.810833
# 4        39.232139     107.813831
# ...            ...            ...
# 8757     39.760000     102.464083
# 8758     39.616842     102.400842
# 8759     39.626692     102.400817
# 8760     39.572217     102.360894
# 8761     39.574164     102.361211
#
# [8762 rows x 2 columns]

# %%
location = locator.reverse(38.441944, 107.555278)

# %%
location.raw
# Out:
# {'place_id': 235594084,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'relation',
#  'osm_id': 1311341,
#  'lat': '39.3262345',
#  'lon': '-4.8380649',
#  'display_name': 'España',
#  'address': {'country': 'España', 'country_code': 'es'},
#  'boundingbox': ['27.4335426', '43.9933088', '-18.3936845', '4.5918885']}

# %%
denver_zipcodes = [80012, 80014, 80110, 80111,80123, 80202, 80203, 80204, 80205, 80206, 80207, 80209, 80210, 80211, 80212, 80214, 80216, 80218, 80219, 80220, 80221, 80222, 80223, 80224, 80226, 80227, 80230, 80231, 80232, 80235, 80236, 80237, 80238, 80239, 80246, 80247, 80249, 80264, 80290, 80293, 80294]

denver_zipcodes
# Out:
# [80012,
#  80014,
#  80110,
#  80111,
#  80123,
#  80202,
#  80203,
#  80204,
#  80205,
#  80206,
#  80207,
#  80209,
#  80210,
#  80211,
#  80212,
#  80214,
#  80216,
#  80218,
#  80219,
#  80220,
#  80221,
#  80222,
#  80223,
#  80224,
#  80226,
#  80227,
#  80230,
#  80231,
#  80232,
#  80235,
#  80236,
#  80237,
#  80238,
#  80239,
#  80246,
#  80247,
#  80249,
#  80264,
#  80290,
#  80293,
#  80294]

# %%
df_zipcodes = pd.read_csv("NBI_Colorado_zipcodes.csv")
df_zipcodes_clean = df_zipcodes.dropna()

df_zipcodes.shape
# count = 0

# for idx, row in df_zipcodes_clean.iterrows():
#     if row["0"] in denver_zipcodes:
#         count += 1
# Out:
# (8762, 2)

# %%
count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-26780ddf2751> in <module>
# ----> 1 count
#
# NameError: name 'count' is not defined

# %%
df_NBI_addresses = pd.read_csv("NBI_Colorado_addresses.csv")
df_NBI_addresses_clean = df_NBI_addresses.dropna()

county_dict = {}

for idx, row in df_NBI_addresses_clean.iterrows():
    if row["county"] in county_dict:
        county_dict[row["county"]] += 1
    else:
        county_dict[row["county"]] = 1

# %%
df_NBI_addresses.shape
# Out:
# (8762, 8)

# %%
zipcodes_list = []
counties_list = []

for idx, row  in df_zipcodes.iterrows():
    zipcodes_list.append(row["0"])
    counties_list.append(df_NBI_addresses.loc[idx, "county"])

# %%
counties_list
# Out:
# ['Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Mesa County',
#  'Mesa County',
#  'Garfield County',
#  'Alamosa County',
#  'Saguache County',
#  'Saguache County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'La Plata County',
#  'Montezuma County',
#  'Montezuma County',
#  'La Plata County',
#  'Montezuma County',
#  'Dolores County',
#  'Montezuma County',
#  'Montezuma County',
#  'Pueblo County',
#  'Pueblo County',
#  'Summit County',
#  'Summit County',
#  'Grand County',
#  'Grand County',
#  'Yuma County',
#  'La Plata County',
#  'Archuleta County',
#  'La Plata County',
#  'La Plata County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Jefferson County',
#  'Hinsdale County',
#  'Eagle County',
#  'Hinsdale County',
#  'Conejos County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'Rio Blanco County',
#  'Rio Blanco County',
#  'Grand County',
#  'Hinsdale County',
#  'Eagle County',
#  'Gunnison County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Rio Grande County',
#  'Alamosa County',
#  'Alamosa County',
#  'Alamosa County',
#  'Alamosa County',
#  'Alamosa County',
#  'Alamosa County',
#  'Alamosa County',
#  'Alamosa County',
#  'Alamosa County',
#  'Alamosa County',
#  'Alamosa County',
#  'Delta County',
#  'Mesa County',
#  'Delta County',
#  'San Miguel County',
#  'San Miguel County',
#  'San Miguel County',
#  'San Miguel County',
#  'Gunnison County',
#  'Gunnison County',
#  'Gunnison County',
#  'Gunnison County',
#  'Ouray County',
#  'Gunnison County',
#  'Gunnison County',
#  'Hinsdale County',
#  'Hinsdale County',
#  'Hinsdale County',
#  'Hinsdale County',
#  'Gunnison County',
#  'Gunnison County',
#  'Gunnison County',
#  'Gunnison County',
#  'Gunnison County',
#  'Gunnison County',
#  'Gunnison County',
#  'Gunnison County',
#  'Delta County',
#  'Gunnison County',
#  'Delta County',
#  'Delta County',
#  'Gunnison County',
#  'Gunnison County',
#  'Gunnison County',
#  'Gunnison County',
#  'Gunnison County',
#  'Rio Blanco County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Mineral County',
#  'Mineral County',
#  'Mineral County',
#  'Conejos County',
#  'Conejos County',
#  'Conejos County',
#  'Conejos County',
#  'Conejos County',
#  'Rio Grande County',
#  'Conejos County',
#  'Conejos County',
#  'Conejos County',
#  'Hinsdale County',
#  'Saguache County',
#  'Hinsdale County',
#  'Rio Grande County',
#  'Rio Grande County',
#  'Mineral County',
#  'Mineral County',
#  'Hinsdale County',
#  'Mineral County',
#  'Mineral County',
#  'Mineral County',
#  'Saguache County',
#  'Saguache County',
#  'Boulder County',
#  'Larimer County',
#  'Larimer County',
#  'Larimer County',
#  'Boulder County',
#  'Grand County',
#  'Boulder County',
#  'Boulder County',
#  'Larimer County',
#  'Clear Creek County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Lake County',
#  'Lake County',
#  'Lake County',
#  'Saguache County',
#  'Saguache County',
#  'Chaffee County',
#  'Chaffee County',
#  'Chaffee County',
#  'Chaffee County',
#  'Custer County',
#  'Huerfano County',
#  'Douglas County',
#  'Park County',
#  'Park County',
#  'Park County',
#  'Park County',
#  'Park County',
#  'Park County',
#  'Jefferson County',
#  'Jefferson County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Dolores County',
#  'San Juan County',
#  'Dolores County',
#  'Dolores County',
#  'La Plata County',
#  'Dolores County',
#  'Montezuma County',
#  'Dolores County',
#  'Dolores County',
#  'Dolores County',
#  'Dolores County',
#  'Dolores County',
#  'Dolores County',
#  'Archuleta County',
#  'Archuleta County',
#  'Mineral County',
#  'Mineral County',
#  'Archuleta County',
#  'Archuleta County',
#  'Hinsdale County',
#  'Hinsdale County',
#  'Hinsdale County',
#  'Hinsdale County',
#  'La Plata County',
#  'La Plata County',
#  'San Juan County',
#  'Pitkin County',
#  'Garfield County',
#  'Pitkin County',
#  'Pitkin County',
#  'Pitkin County',
#  'Pitkin County',
#  'Pitkin County',
#  'Pitkin County',
#  'Gunnison County',
#  'Garfield County',
#  'Eagle County',
#  'Eagle County',
#  'Eagle County',
#  'Mesa County',
#  'Garfield County',
#  'Montezuma County',
#  'Grand County',
#  'Eagle County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Grand County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'Jackson County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'La Plata County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montezuma County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Montrose County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  nan,
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Summit County',
#  'Summit County',
#  'Summit County',
#  'Summit County',
#  'Summit County',
#  'Summit County',
#  'Summit County',
#  'Summit County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Routt County',
#  'Grand County',
#  'Grand County',
#  'Moffat County',
#  'Larimer County',
#  'Larimer County',
#  'Larimer County',
#  'Larimer County',
#  'Boulder County',
#  'Boulder County',
#  'Grand County',
#  'Larimer County',
#  'Grand County',
#  'Grand County',
#  'Boulder County',
#  'Grand County',
#  'Garfield County',
#  'Garfield County',
#  'City and County of Broomfield',
#  'City and County of Broomfield',
#  'Moffat County',
#  'Moffat County',
#  'Moffat County',
#  'Jackson County',
#  'Jackson County',
#  'Larimer County',
#  'Larimer County',
#  'Larimer County',
#  'Larimer County',
#  'Larimer County',
#  'Larimer County',
#  'Larimer County',
#  'Larimer County',
#  'Weld County',
#  'Weld County',
#  'Larimer County',
#  'Larimer County',
#  'Larimer County',
#  'Larimer County',
#  'Larimer County',
#  'Larimer County',
#  'Weld County',
#  'Weld County',
#  'Weld County',
#  'Weld County',
#  'Weld County',
#  'Weld County',
#  'Weld County',
#  'Larimer County',
#  'Larimer County',
#  'Larimer County',
#  'Weld County',
#  'Weld County',
#  'Weld County',
#  'Larimer County',
#  'Weld County',
#  'Larimer County',
#  'Laramie County',
#  'Weld County',
#  'Weld County',
#  'Weld County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Weld County',
#  'Weld County',
#  'Logan County',
#  'Logan County',
#  'Logan County',
#  'Logan County',
#  'Logan County',
#  'Logan County',
#  'Logan County',
#  'Logan County',
#  'Logan County',
#  'Logan County',
#  'Logan County',
#  'Logan County',
#  'Logan County',
#  'Logan County',
#  'Logan County',
#  'Logan County',
#  'Logan County',
#  'Logan County',
#  'Logan County',
#  'Logan County',
#  'Logan County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Logan County',
#  'Logan County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Sedgwick County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Arapahoe County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'El Paso County',
#  'Las Animas County',
#  'Las Animas County',
#  'Alamosa County',
#  'Archuleta County',
#  'Archuleta County',
#  'Archuleta County',
#  'Archuleta County',
#  'Archuleta County',
#  'Archuleta County',
#  'Archuleta County',
#  'Archuleta County',
#  'Archuleta County',
#  'Archuleta County',
#  'Archuleta County',
#  'Archuleta County',
#  'Archuleta County',
#  'Archuleta County',
#  'Archuleta County',
#  'Archuleta County',
#  'Archuleta County',
#  'La Plata County',
#  'Adams County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Douglas County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Archuleta County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Jefferson County',
#  'Pitkin County',
#  'Pitkin County',
#  'Pitkin County',
#  'Adams County',
#  'Adams County',
#  'Denver County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Denver County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Adams County',
#  'Arapahoe County',
#  'Adams County',
#  'Adams County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  nan,
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Arapahoe County',
#  'Adams County',
#  'Denver County',
#  'Denver County',
#  'Eagle County',
#  'Eagle County',
#  'Eagle County',
#  'Eagle County',
#  'Eagle County',
#  'Eagle County',
#  'Moffat County',
#  'Moffat County',
#  'Moffat County',
#  ...]

# %%
coordinates_for_mapping = []

for idx, county in enumerate(counties_list):
    if county == 'El Paso County':
        coordinates_for_mapping.append(zipcode)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-feca72e6c212> in <module>
#       3 for idx, county in enumerate(counties_list):
#       4     if county == 'El Paso County':
# ----> 5         coordinates_for_mapping.append(zipcode)
#
# NameError: name 'zipcode' is not defined

# %%
county_dict
# Out:
# {'Montrose County': 64,
#  'Montezuma County': 16,
#  'La Plata County': 26,
#  'Yuma County': 11,
#  'El Paso County': 368,
#  'Adams County': 257,
#  'Gunnison County': 6,
#  'Rio Grande County': 29,
#  'Clear Creek County': 19,
#  'Pitkin County': 22,
#  'Eagle County': 41,
#  'Grand County': 17,
#  'Jackson County': 10,
#  'Routt County': 17,
#  'Summit County': 5,
#  'Boulder County': 123,
#  'Larimer County': 185,
#  'Weld County': 297,
#  'Jefferson County': 153,
#  'Logan County': 44,
#  'Archuleta County': 16,
#  'Arapahoe County': 128,
#  'Douglas County': 132,
#  'Moffat County': 11,
#  'Phillips County': 6,
#  'Baca County': 9,
#  'Bent County': 23,
#  'Morgan County': 69,
#  'Washington County': 23,
#  'Las Animas County': 60,
#  'Chaffee County': 33,
#  'Conejos County': 34,
#  'Mineral County': 6,
#  'Costilla County': 17,
#  'Custer County': 7,
#  'Cheyenne County': 22,
#  'Rio Blanco County': 5,
#  'Denver County': 57,
#  'Delta County': 34,
#  'Dolores County': 3,
#  'Gilpin County': 5,
#  'Elbert County': 13,
#  'Garfield County': 22,
#  'Fremont County': 51,
#  'Mesa County': 151,
#  'Lake County': 8,
#  'Park County': 14,
#  'Lincoln County': 14,
#  'Kit Carson County': 18,
#  'Huerfano County': 23,
#  'Teller County': 5,
#  'Pueblo County': 125,
#  'Kiowa County': 3,
#  'San Miguel County': 9,
#  'Ouray County': 16,
#  'Saguache County': 4,
#  'Otero County': 97,
#  'Prowers County': 40,
#  'Alamosa County': 2,
#  'San Juan County': 2,
#  'City and County of Broomfield': 2}

# %%
import operator
max(county_dict.items(), key=operator.itemgetter(1))[0]
# Out:
# 'El Paso County'

# %%
counties_and_coordinates_df = pd.read_csv('counties_and_coordinates_df.csv')
counties_and_coordinates_df
# Out:
#       Unnamed: 0         counties  decimal_lats  decimal_longs
# 0              0  Montrose County     38.441944     252.444722
# 1              1  Montrose County     38.446944     252.444722
# 2              2  Montrose County     38.463889     252.450278
# 3              3      Mesa County     39.225556     252.189167
# 4              4      Mesa County     39.232139     252.186169
# ...          ...              ...           ...            ...
# 8741        8741      Yuma County     39.760000     257.535917
# 8742        8742      Yuma County     39.616842     257.599158
# 8743        8743      Yuma County     39.626692     257.599183
# 8744        8744      Yuma County     39.572217     257.639106
# 8745        8745      Yuma County     39.574164     257.638789
#
# [8746 rows x 4 columns]

# %%
decimal_lats_ElPaso = []
decimal_longs_ElPaso = []

for idx, row in counties_and_coordinates_df.iterrows():
    if row['counties'] == 'El Paso County':
        decimal_lats_ElPaso.append(row['decimal_lats'])
        decimal_longs_ElPaso.append(row['decimal_longs'])

# %%
decimal_longs_ElPaso
# Out:
# [255.2812,
#  255.2636,
#  255.2627,
#  255.2589,
#  255.2517,
#  255.2813,
#  255.2254,
#  255.1345,
#  255.1364,
#  255.27,
#  255.2743,
#  255.27900000000002,
#  255.47975277777775,
#  255.48220833333332,
#  255.4674444444444,
#  255.46534722222225,
#  255.47844166666667,
#  255.31771944444444,
#  255.28766944444442,
#  255.28766666666667,
#  255.1561111111111,
#  255.1555833333333,
#  255.15091666666663,
#  255.15027777777775,
#  255.1675055555556,
#  255.1661111111111,
#  255.1623305555556,
#  255.17638888888888,
#  39.578075000000005,
#  39.78248055555555,
#  39.78276388888889,
#  39.78158055555556,
#  39.63630555555555,
#  39.63180555555556,
#  39.646433333333334,
#  39.64749166666667,
#  39.62777777777778,
#  39.62466111111111,
#  40.72051666666667,
#  40.62015,
#  40.607725,
#  ...]

# %%
ElPaso_weatherstns_df = pd.read_csv("NOAA_EL_PASO_2019.csv")
ElPaso_weatherstns_df
# Out:
# C:\Users\tobby\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (7,9,11,13,15,17,19,27,33,35,37,43,45,49,53,57,59,61,63,65) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            STATION                                       NAME   LATITUDE  \
# 0      US1COEP0291             COLORADO SPRINGS 8.2 SE, CO US  38.742451
# 1      US1COEP0291             COLORADO SPRINGS 8.2 SE, CO US  38.742451
# 2      US1COEP0291             COLORADO SPRINGS 8.2 SE, CO US  38.742451
# 3      US1COEP0291             COLORADO SPRINGS 8.2 SE, CO US  38.742451
# 4      US1COEP0291             COLORADO SPRINGS 8.2 SE, CO US  38.742451
# ...            ...                                        ...        ...
# 25206  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.810000
# 25207  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.810000
# 25208  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.810000
# 25209  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.810000
# 25210  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.810000
#
#        LONGITUDE  ELEVATION        DATE   AWND AWND_ATTRIBUTES  DAPR  \
# 0     -104.72506     1748.0  2019-01-01    NaN             NaN   NaN
# 1     -104.72506     1748.0  2019-01-02    NaN             NaN   NaN
# 2     -104.72506     1748.0  2019-01-03    NaN             NaN   NaN
# 3     -104.72506     1748.0  2019-01-04    NaN             NaN   NaN
# 4     -104.72506     1748.0  2019-01-05    NaN             NaN   NaN
# ...          ...        ...         ...    ...             ...   ...
# 25206 -104.68840     1884.0  2019-12-27   4.70             ,,W   NaN
# 25207 -104.68840     1884.0  2019-12-28  17.22             ,,W   NaN
# 25208 -104.68840     1884.0  2019-12-29   9.40             ,,W   NaN
# 25209 -104.68840     1884.0  2019-12-30   6.49             ,,W   NaN
# 25210 -104.68840     1884.0  2019-12-31   6.26             ,,W   NaN
#
#       DAPR_ATTRIBUTES  ...  WT06 WT06_ATTRIBUTES  WT07 WT07_ATTRIBUTES  WT08  \
# 0                 NaN  ...   NaN             NaN   NaN             NaN   NaN
# 1                 NaN  ...   NaN             NaN   NaN             NaN   NaN
# 2                 NaN  ...   NaN             NaN   NaN             NaN   NaN
# 3                 NaN  ...   NaN             NaN   NaN             NaN   NaN
# 4                 NaN  ...   NaN             NaN   NaN             NaN   NaN
# ...               ...  ...   ...             ...   ...             ...   ...
# 25206             NaN  ...   NaN             NaN   NaN             NaN   1.0
# 25207             NaN  ...   NaN             NaN   NaN             NaN   1.0
# 25208             NaN  ...   NaN             NaN   NaN             NaN   NaN
# 25209             NaN  ...   NaN             NaN   NaN             NaN   NaN
# 25210             NaN  ...   NaN             NaN   NaN             NaN   NaN
#
#       WT08_ATTRIBUTES  WT09 WT09_ATTRIBUTES  WT11 WT11_ATTRIBUTES
# 0                 NaN   NaN             NaN   NaN             NaN
# 1                 NaN   NaN             NaN   NaN             NaN
# 2                 NaN   NaN             NaN   NaN             NaN
# 3                 NaN   NaN             NaN   NaN             NaN
# 4                 NaN   NaN             NaN   NaN             NaN
# ...               ...   ...             ...   ...             ...
# 25206             ,,W   NaN             NaN   NaN             NaN
# 25207             ,,W   1.0             ,,W   NaN             NaN
# 25208             NaN   NaN             NaN   NaN             NaN
# 25209             NaN   NaN             NaN   NaN             NaN
# 25210             NaN   NaN             NaN   NaN             NaN
#
# [25211 rows x 66 columns]

# %%
station_list = []
station_lats_list = []
station_longs_list = []

for idx, row in ElPaso_weatherstns_df.iterrows():
    station_list.append(row['STATION'])
    station_lats_list.append(row['LATITUDE'])
    station_longs_list.append(row['LONGITUDE'])

# %%
unique_stations = []
unique_station_lats = []
unique_station_longs = []



for idx, station in enumerate(station_list):
    if station not in unique_stations:
        unique_stations.append(station)
        unique_station_lats.append(station_lats_list[idx])
        unique_station_longs.append(station_longs_list[idx] + 360)

# %%
print(len(unique_stations))
print(len(decimal_lats_ElPaso))
# Out:
# 96
# 661

# %%
import folium
from folium.plugins import FastMarkerCluster # python map data visualization tool

folium_map = folium.Map(zoom_start=12)


FastMarkerCluster(data=list(zip(decimal_lats_ElPaso, decimal_longs_ElPaso))).add_to(folium_map)

for point in range(0, len(unique_stations)):
    folium.Marker((unique_station_lats[point], unique_station_longs[point]), popup=unique_stations[point]).add_to(folium_map)

folium.LayerControl().add_to(folium_map)
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def get_address(df, geolocator, lat_field, long_field):
    try:
        location = geolocator.reverse((df[lat_field], df[long_field]))
        return location.raw['address']
    except:
        return None

# %%
addresses[0]

# %%
def dms2dd(s):

    minutes = s[-6:-4]
    seconds = s[-4:]
    seconds_decimal = s[-4:-2] + "." +s[-2:]

    temp_dms = minutes
    temp_dms = temp_dms + seconds
    
    if temp_dms in s:
        degrees = s.replace(temp_dms,'')
    
    dd = float(degrees) + float(minutes)/60 + float(seconds_decimal)/(60*60);
    
    return dd
    
dms2dd(str(df["LONG_017"][0]))
dms2dd(str(df["LAT_016"][0]))
# Out:
# 38.44194444444444

# %%
decimal_lats = []
decimal_longs = []


for index, row in df.iterrows():
    str_lat = str(row["LAT_016"])
    str_long = str(row["LONG_017"])
    
    if len(str_lat) < 8 or len(str_long) < 8:
        continue
    
    decimal_lat = dms2dd(str_lat)
    decimal_long = dms2dd(str_long)
    
    decimal_long = 360 - decimal_long
    
    decimal_lats.append(decimal_lat)
    decimal_longs.append(decimal_long)
    
decimal_lats
decimal_longs

df_new = pd.DataFrame()
df_new['decimal_lats'] = decimal_lats
df_new['decimal_longs'] = decimal_longs

df_new
# Out:
#       decimal_lats  decimal_longs
# 0        38.441944     252.444722
# 1        38.446944     252.444722
# 2        38.463889     252.450278
# 3        39.225556     252.189167
# 4        39.232139     252.186169
# ...            ...            ...
# 8757     39.760000     257.535917
# 8758     39.616842     257.599158
# 8759     39.626692     257.599183
# 8760     39.572217     257.639106
# 8761     39.574164     257.638789
#
# [8762 rows x 2 columns]

# %%
addresses = df_new.apply(get_address, axis=1, geolocator=geolocator, lat_field='decimal_lats', long_field='decimal_longs')

# %%
addresses
# Out:
# 0       None
# 1       None
# 7       None
# 9       None
# 10      None
#         ...
# 8754    None
# 8758    None
# 8759    None
# 8760    None
# 8761    None
# Length: 6454, dtype: object
