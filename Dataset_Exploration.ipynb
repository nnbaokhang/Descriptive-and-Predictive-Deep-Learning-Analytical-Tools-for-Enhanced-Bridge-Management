# %% [markdown]
# # After reading through the dataset initially we came to the conclusion that we will consider the following features for our data exploration (We list and define them below based on the provided Data Catalog):
# 1. **Sufficieny Rating** - A method of evaluating highway bridge data by calculating four separate factors to obtain a numeric value indicative of bridge sufficiency to remain in service. The result of this method is a percentage in chich 100 percent would represent an entirely sufficient bridge and percent would represent an entirely insufficient or deficient bridge.
# 2. **County Code** - Counties identified by Federal Information Processing Standards (FIPS) codes given in the current version of the Census of Population and Housing - Geographic Identification Code Scheme.
# 3. **Max Clr** - Code the minimum vertical clearance over the inventory route identified in Item 5, whether the route is "on" the structure or "under" the structure. The minimum clearance for a 3-meter width of the pavement or traveled part of the roadway where the clearance is the greatest shall be recorded and coded as a 4-digit number truncated to the hundredth of a meter (with an assumed decimal point). For structures having multiple openings, clearance for each opening shall be recorded, but only the greatest of the "minimum clearances" for the two or more openings shall be coded regardless of the direction of travel. This would be the practical maximum clearance. When no restriction exists or when the restriction is 30 meters or greater, code 9999. Coding of actual clearances between 30.0 and 99.99 meters to an exact measurement is optional.
# 4. **Custodian** - The actual name(s) of the agency(s) responsible for the maintenance of the structure shall be recorded on the inspection form. There are codes in the catalog showing which numerical code go to which agency name.
# 5. **Owner** - The actual name(s) of the owner(s) of the bridge shall be recorded on the inspection form. Codes in the catalog can be refered to the actual names of the owners.
# 6. Functional Class - Functional classification of the inventory route such as: Principal Arterial - Interstate, Principal Arterial - Other, local, etc.
# 7. **Year Built** - Year of construction of the structure. All 4 digits of the year of construction completion.
# 8. **Lanes on** - Number of lanes being carried by the structure.
# 9. **Lanes Under** - Number of lanes being crossed over by the structure.
# 10. **Average Daily Traffic (ADT)** - 6-digit number showing the average daily traffic volume for the inventory route identified in Item 5.
# 11. **Year of ADT** - The year represented by the ADT.
# 12. **Design Load** - The live load for which the structure was designed such as: Pedestrian, Railroad, etc.
# 13. **Apr Rdwy Width** - Approach Roadway Width is a 4-digit number representing the normal width of usable roadway approaching the structure measured to the nearest tenth of a meter.
# 14. **Median** - 1-digit code representing if median is non-existent, open, closed with no barrier or closed non-mountable barriers.
# 15. **Skew** - The skew angle between the centerline of a pier and a line normal to the roadway centerline.
# 16. **Posting Status** - This item provides information about the actual operational status of a structure.
# 17. **Main Mat/Des gn 43A** - Kind of material and/or design based on main spans.
# 18. **Main Mat/Des gn 43B** - Type of design and/or construction based on main spans.
# 19. **Appr Mat/Des gn 44A** - Kind of material and/or design based on approach spans.
# 20. **Appr Mat/Des gn 44B** - Type of design and/or construction based on approach spans.
# 21. **Main Spans Unit** - The number of spans in the main or major unit.
# 22. **Approach Spans** - The number of spans in the approach spans to the major bridge or number of spans of material different from that of the major bridge.
# 23. **Horiz Clr** - Total horizontal clearance for the inventory route identified in Item 5.
# 24. **Max Span** - The length of the maximum span.
# 25. **Str Length** - Structure length is a 6-digit number representing the length of the structure to the nearest tenth of a meter.
# 26. **Curb Wdth L/R 50A** - Left curb or sidewalk width.
# 27. **Curb Wdth L/R 50B** - Right curb or sidewalk width.
# 28. **Width Curb to Curb** - The most restrictive minimum distance between curbs or rails on the structure roadway.
# 29. **Width Out to Out** - 4-digit number to show the out-to-out width to the nearest tenth of a meter.
# 30. **Deck Area** - Area of the deck.
# 31. **Deck** - This item describes the overall condition rating of the deck.
# 32. **Super** - This item describes the physical condition of all structural members.
# 33. **Sub** - This item describes the physical condition of piers, abutments, piles, fenders, footings, or other components.
# 34. **Operating Rating** - This capacity rating, referred to as the operating rating, will result in the absolute maximum permissible load level to which the structure may be subjected for the vehicle type used in the rating.
# 35. **Asph/Fill Thick** - This capacity rating, referred to as the inventory rating, will result in a load level which can safely utilize an existing structure for an indefinite period of time.
# 36. **Str Evaluation** - Structural evalutation calculated by Edit/Update Program.
# 37. **Deck Geometry** - Calculated by Edit/Update Program. Includes two evaluations: curb-topcube or face-to-face of rail bridge width and the minum vertical clearance over the bridge roadway.
# 38. **Undrclr Vert/Hor** - calculated by Edit/Update Program. Vertical and Horizontal underclearances are measured from the through roadway to the superstructure or substructure units, respectively.
# 39. **Posting** - The National Bridge Inspection Standards require the posting of load limits only if the maximum legal load configurations in the State exceeds the load permitted under the operating rating.
# 40. **Waterway Adequacy** - This item appraises the waterway opening with respect to passage of flow through the bridge.
# 41. **Approach Alignment** - Based on the adequacy of the approach roadway alignment. This item identifies those bridges which do not functino properly or adequately due to the alignment of the approaches.
# 42. **Highway System** - For inventory route identified, indicate whether the inventory route is on the National Highway System or not on that system.
# 43. **Deck Type** - Type of deck system on bridge.
# 44. **Wearing Surface** -  Informatoin on the wearing surface and protective system of the bridge deck.
# 45. **Membrane** - Type of protective membrane.
# 46. **Truck ADT** - 2-digit percentage showing the percentage of Average Daily Traffic that is truck traffic.
# 47. **Pier Protection** - Indicates the presence and adequacy of pier or abutment protection features such as fenders, dolphins, etc.
# 48. **NBIS Length** - Does the structure meet or exceed the minimum length specified to be designated as a bridge for National Bridge Inspection standards purposes?
# 49. **Scour Critical** - Single-digit code to identify current status of the bridge regarding its vulnerability to scour.
# 50. **Scour Watch** - Scour assessment.
# 51. **CDOT Str Type** - CDOT structure type.
# 52. **CDOT Constr Type** - CDOT construction type.
# 53. **Bridge Name** - Name of bridge.
# 54. **Inspection Date** - Date inspection was carried out.
# 55. **SD/FO** - Structurally Deficient or Functionally Obsolete: 1=Structurally Deficient, 2=Functionally Obsolete, 0=Not Deficient, N=Not Applicable
# 56. **Place Code** - Cities, towns, townships, villages, and other census-designated places identified using Federal Information Processing Standards (FIPS) codes given in the current version of the Census of Population and Housing - Geographic Identification Code Scheme.
# 57. **Features Intersected** - This item contains a description of the features intersected by the structure and a critical facility indicator.
# 58. **Facility Carried** - The facility being carried by the structure shall be recorded and coded. In all situations this item describes the user "on" the structure.
# 59. **Location** - This item contains a narrative description of the bridge location.
# 60. **Latitude** - Latitude in degrees, minutes, and seconds to the nearest hundredth of a second. The point of the coordinate may be the beginning of the bridge in the direction of the inventory or any other consistent point of reference on the bridge which is compatible with the LRS.
# 61. **Longitude** - Same specifications as Latitude but for Longitude in this case.
# 62. **

# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import xlrd

# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the dataset and view the first five observations in the dataset

# %%
df = pd.read_excel("Copy of SIA_data_Major_C.xlsx")
df.head()
# Out:
#     Bridge Name            Inspection Date  Sufficiency Rating SD/FO  \
# 0   D-01-CC-014  2014-10-02T00:00:00-06:00                96.9     0
# 1   D-01-CC-017  2014-10-02T00:00:00-06:00                78.5     2
# 2   D-01-CC-019  2014-10-02T00:00:00-06:00                78.6     2
# 3   D-01-CC-020  2014-10-02T00:00:00-06:00                79.3     0
# 4  D-01-CC-030A  2014-10-02T00:00:00-06:00                95.3     0
#
#    County Code 3  Place Code 4 Feature Intersected 6 Facility Carried 7  \
# 0             31         20000          CHERRY CREEK    LITTLE RAVEN ST
# 1             31         20000          CHERRY CREEK  WB WEWATTA STREET
# 2             31         20000          CHERRY CREEK  EB WEWATTA STREET
# 3             31         20000          CHERRY CREEK           WAZEE ST
# 4             31         20000          CHERRY CREEK           BLAKE ST
#
#                  Location 9  Max Clr 10  ...  Membrane 108B  \
# ...

# %% [markdown]
# # Remove columns not highlighted in original excel sheet

# %%
del df['Feature Intersected 6']
del df['Bridge Name']
del df['Inspection Date']
del df['SD/FO']
del df['Place Code 4']
del df['Facility Carried 7']
del df['Location 9']
del df['Latitude 16']
del df['Longitude 17']
del df['Sfty Rail 36a']
del df['Sfty Rail 36b']
del df['Sfty Rail 36c']
del df['Sfty Rail 36d']
del df['Rail ht36h']
del df['Hist Signif 37']
del df['Service on/un 42A']
del df['Service on/un 42B']
del df['Min Undrclr Ref 54A']
del df['Min Undrclr 54B']
del df['Min Lat Clrnce Ref R 55A']
del df['Min Lat Undrclr R 55B']
del df['Channel/Protection 61']
del df['Culvert 62']
del df['Oprtng Rtg Method 63']
del df['Inv Rtng Method 65']
del df['Inventory Rating 66']
del df['Insp Team Indicator 90B']
del df['Inspector Name 90C']
del df['Frequency 91']
del df['FC Inspection Date 93A']
del df['UW Inspection Date 93B']
del df['SI Date 93C']
del df['Direction of Traffic 102']
del df['Str Rating Date 130']
del df['Posting Status 41']
del df['Undrclr Vert/Hor 69']
del df['NBIS Length 112']
del df['Scour Watch 113M']
del df['CDOT Str Type 120A']
df
# Out:
#      Sufficiency Rating  County Code 3  Max Clr 10  Custodian 21  Owner 22  \
# 0                  96.9             31   30.450001             4         4
# 1                  78.5             31   30.450001             4         4
# 2                  78.6             31   30.450001             4         4
# 3                  79.3             31   30.450001             4         4
# 4                  95.3             31   30.450001             4         4
# ..                  ...            ...         ...           ...       ...
# 203                80.5             31   99.989998             4         4
# 204                -2.0             31    4.542000             4         4
# 205                80.1             31   99.989998             4         4
# 206                80.1             31   99.989998             4         4
# 207                99.9             31   30.174999             4         4
#
# ...

# %% [markdown]
# # Get various summary statistics such as: count, mean, standard deviation, minimum and maximum quantiles of each column

# %%
df.describe()
# Out:
#        Sufficiency Rating  County Code 3  Max Clr 10  Custodian 21  \
# count          208.000000          208.0  208.000000    208.000000
# mean            82.094231           31.0   66.280788      4.370192
# std             15.638175            0.0   36.097811      2.799668
# min             -2.000000           31.0    4.542000      4.000000
# 25%             76.050000           31.0   30.450001      4.000000
# 50%             83.450000           31.0   99.989998      4.000000
# 75%             95.300000           31.0   99.989998      4.000000
# max             99.900000           31.0   99.989998     27.000000
#
#          Owner 22  Functional Class 26  Year Built 27  Lanes on 28A  \
# count  208.000000           208.000000     208.000000    208.000000
# mean     4.331731            16.812500    1982.274038      3.086538
# std      2.748834             1.982639      18.151986      1.847367
# min      4.000000            12.000000    1925.000000      1.000000
# ...

# %% [markdown]
# # Get total number of rows and columns in the dataset

# %%
df.shape
# Out:
# (208, 49)

# %% [markdown]
# # Get data types of each column, we desire only numerical data types

# %%
df.dtypes # Removed additional items that were highlighted in excel sheet, decided to keep only numerical features ex: int64 & float64
# Out:
# Sufficiency Rating       float64
# County Code 3              int64
# Max Clr 10               float64
# Custodian 21               int64
# Owner 22                   int64
# Functional Class 26        int64
# Year Built 27              int64
# Lanes on 28A               int64
# Lanes Under 28B            int64
# ADT 29                     int64
# Year of ADT 30             int64
# Design Load 31           float64
# Apr Rdwy Width 32        float64
# Median 33                  int64
# Skew 34                    int64
# Main Mat/Desgn 43A         int64
# Main Mat/Desgn 43B         int64
# Appr Mat/Desgn 44A         int64
# Appr Mat/Desgn 44B         int64
# Main Spans Unit 45         int64
# Approach Spans 46          int64
# Horiz Clr 47             float64
# Max Span 48              float64
# Str Length 49            float64
# Curb Wdth L/R 50A        float64
# Curb Wdth L/R 50B        float64
# Width Curb to Curb 51    float64
# Width Out to Out 52      float64
# ...

# %% [markdown]
# # View columns, their corresponding data types and whether they contain null  values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 49 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sufficiency Rating     208 non-null    float64
#  1   County Code 3          208 non-null    int64
#  2   Max Clr 10             208 non-null    float64
#  3   Custodian 21           208 non-null    int64
#  4   Owner 22               208 non-null    int64
#  5   Functional Class 26    208 non-null    int64
#  6   Year Built 27          208 non-null    int64
#  7   Lanes on 28A           208 non-null    int64
#  8   Lanes Under 28B        208 non-null    int64
#  9   ADT 29                 208 non-null    int64
#  10  Year of ADT 30         208 non-null    int64
#  11  Design Load 31         204 non-null    float64
#  12  Apr Rdwy Width 32      208 non-null    float64
#  13  Median 33              208 non-null    int64
# ...

# %% [markdown]
# # Check if there are any null values in dataframe

# %%
print(df.isnull().values.any())
# Out:
# True

# %% [markdown]
# # Get total number of null values

# %%
print(df.isnull().sum().sum())
# Out:
# 524

# %% [markdown]
# # Check null value counts from each column

# %%
print(df.isnull().sum())
# Out:
# Sufficiency Rating        0
# County Code 3             0
# Max Clr 10                0
# Custodian 21              0
# Owner 22                  0
# Functional Class 26       0
# Year Built 27             0
# Lanes on 28A              0
# Lanes Under 28B           0
# ADT 29                    0
# Year of ADT 30            0
# Design Load 31            4
# Apr Rdwy Width 32         0
# Median 33                 0
# Skew 34                   0
# Main Mat/Desgn 43A        0
# Main Mat/Desgn 43B        0
# Appr Mat/Desgn 44A        0
# Appr Mat/Desgn 44B        0
# Main Spans Unit 45        0
# Approach Spans 46         0
# Horiz Clr 47              0
# Max Span 48               0
# Str Length 49             0
# Curb Wdth L/R 50A         0
# Curb Wdth L/R 50B         0
# Width Curb to Curb 51     0
# Width Out to Out 52       0
# Deck Area                 0
# Min Lat Undrclr L 56      0
# Deck 58                  59
# Super 59                 59
# Sub 60                   59
# ...

# %% [markdown]
# # Remove all null values and copy new dataframe with no null values to df1

# %%
df1 = df.copy()

df1.dropna(inplace=True)

# %% [markdown]
# # Check all columns again and ensure no null values

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105 entries, 0 to 207
# Data columns (total 49 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sufficiency Rating     105 non-null    float64
#  1   County Code 3          105 non-null    int64
#  2   Max Clr 10             105 non-null    float64
#  3   Custodian 21           105 non-null    int64
#  4   Owner 22               105 non-null    int64
#  5   Functional Class 26    105 non-null    int64
#  6   Year Built 27          105 non-null    int64
#  7   Lanes on 28A           105 non-null    int64
#  8   Lanes Under 28B        105 non-null    int64
#  9   ADT 29                 105 non-null    int64
#  10  Year of ADT 30         105 non-null    int64
#  11  Design Load 31         105 non-null    float64
#  12  Apr Rdwy Width 32      105 non-null    float64
#  13  Median 33              105 non-null    int64
# ...

# %% [markdown]
# # Based on further inspection of dataset, I trimmed down the features I explored to essential columns for plot readability (The number of features we select can always be played around with)

# %%
selected_columns = df[['Sufficiency Rating', 'Year Built 27', 'ADT 29', 'Operating Rating 64', 'Design Load 31', 'Lanes on 28A', 'Deck Area', 'Apr Rdwy Width 32', 'Horiz Clr 47', 'Max Span 48']]

# %%
selected_columns
# Out:
#      Sufficiency Rating  Year Built 27  ADT 29  Operating Rating 64  \
# 0                  96.9           1995     698            72.300003
# 1                  78.5           1998    4773            72.199997
# 2                  78.6           1998    4106            74.699997
# 3                  79.3           1985    7736            63.900002
# 4                  95.3           1984    9815            46.599998
# ..                  ...            ...     ...                  ...
# 203                80.5           2003       3            81.599998
# 204                -2.0           1940     665             0.000000
# 205                80.1           2004    9319            60.799999
# 206                80.1           2004    9419            60.799999
# 207                99.9           2006    1000            36.299999
#
#      Design Load 31  Lanes on 28A  Deck Area  Apr Rdwy Width 32  Horiz Clr 47  \
# ...

# %% [markdown]
# # We employ box plots on our features to get an understanding of distributions in our data, we can also see here that some of our features contain outliers

# %%
selected_columns.plot(kind='box', subplots=True, layout=(5,2), sharex=False, sharey=False, figsize=(20, 20), color='deeppink')
# Out:
# Sufficiency Rating        AxesSubplot(0.125,0.749828;0.352273x0.130172)
# Year Built 27          AxesSubplot(0.547727,0.749828;0.352273x0.130172)
# ADT 29                    AxesSubplot(0.125,0.593621;0.352273x0.130172)
# Operating Rating 64    AxesSubplot(0.547727,0.593621;0.352273x0.130172)
# Design Load 31            AxesSubplot(0.125,0.437414;0.352273x0.130172)
# Lanes on 28A           AxesSubplot(0.547727,0.437414;0.352273x0.130172)
# Deck Area                 AxesSubplot(0.125,0.281207;0.352273x0.130172)
# Apr Rdwy Width 32      AxesSubplot(0.547727,0.281207;0.352273x0.130172)
# Horiz Clr 47                 AxesSubplot(0.125,0.125;0.352273x0.130172)
# Max Span 48               AxesSubplot(0.547727,0.125;0.352273x0.130172)
# dtype: object

# %% [markdown]
# # Let's handle the issue of outliers via:
# **IQR score** or interquartile range which is the first quartile subtracted from the third quartile, this is a measure of the dispersion similar to standard deviation or variance but is much more robust against outliers

# %%
Q1 = selected_columns.quantile(0.25)
Q3 = selected_columns.quantile(0.75)
IQR = Q3 - Q1

print(IQR)

selected_columns_o = selected_columns[~((selected_columns < (Q1 - 1.5 * IQR)) |(selected_columns > (Q3 + 1.5 * IQR))).any(axis=1)]
selected_columns_o.shape
# Out:
# Sufficiency Rating        19.250000
# Year Built 27             28.250000
# ADT 29                 10994.750000
# Operating Rating 64       35.700001
# Design Load 31             5.000000
# Lanes on 28A               2.000000
# Deck Area                729.250000
# Apr Rdwy Width 32         14.249335
# Horiz Clr 47               4.534250
# Max Span 48               20.726000
# dtype: float64
# C:\Users\tobby\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# (156, 10)

# %% [markdown]
# # We again plot boxplots and can observe an improvement in the distribution of our data

# %%
selected_columns_o.plot(kind='box', subplots=True, layout=(5,2), sharex=False, sharey=False, figsize=(20, 20), color='deeppink')
# Out:
# Sufficiency Rating        AxesSubplot(0.125,0.749828;0.352273x0.130172)
# Year Built 27          AxesSubplot(0.547727,0.749828;0.352273x0.130172)
# ADT 29                    AxesSubplot(0.125,0.593621;0.352273x0.130172)
# Operating Rating 64    AxesSubplot(0.547727,0.593621;0.352273x0.130172)
# Design Load 31            AxesSubplot(0.125,0.437414;0.352273x0.130172)
# Lanes on 28A           AxesSubplot(0.547727,0.437414;0.352273x0.130172)
# Deck Area                 AxesSubplot(0.125,0.281207;0.352273x0.130172)
# Apr Rdwy Width 32      AxesSubplot(0.547727,0.281207;0.352273x0.130172)
# Horiz Clr 47                 AxesSubplot(0.125,0.125;0.352273x0.130172)
# Max Span 48               AxesSubplot(0.547727,0.125;0.352273x0.130172)
# dtype: object

# %% [markdown]
# # Here we observe the contcentrations and distributions of our data via density plots

# %%
selected_columns_o.plot(kind='density', subplots=True, layout=(5,2), sharex=False, figsize=(20, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002376FFEC5C8>,
# ...
#       dtype=object)

# %% [markdown]
# # We utilize pairplot to get an initial understanding of correlations between our features

# %%
fig = plt.figure(figsize = (15, 15))

sns.pairplot(selected_columns_o, vars=['Sufficiency Rating', 'Year Built 27', 'ADT 29', 'Operating Rating 64', 'Design Load 31', 'Lanes on 28A', 'Deck Area', 'Apr Rdwy Width 32', 'Horiz Clr 47', 'Max Span 48'])

plt.show()

# %% [markdown]
# # A more precise correlation between features can be visualized via a correlation matrix
#
# We have positive and negative correlation coefficients:
#
# - Positive coefficients indicate that when the value of one variable increases, the value of the other variable also tends to increase. Positive relationships produce an upward slope on a scatterplot.
#
# - Negative coefficients represent cases when the value of one variable increases, the value of the other variable tends to decrease. Negative relationships produce a downward slope.
#
# We can interpret the correlation coefficients as such:
#
# - +1 - A perfect positive relationship
#
# - 0.8 - A fairly strong positive relationship
#
# - 0.6 - A moderate positive relationship
#
# - 0 - No relationship. As one value increases, there is no tendency for the other value to change in a specific direction.
#
# - -1 - A perfect negative relationship
#
# - -0.8 - A fairly strong negative relationship
#
# - -0.6 - A moderate negative relationship
#
# Because we are performing regression analysis we may want to remove highly correlated features as this can lead to multicolinearity which is when one feature can be linearly predicted from others with substantial accuracy. This can then lead to solutions that vary and can be numerically unstable. Essentially, the shortest description or the minimum description length of the data is the best model.

# %%
fig = plt.figure(figsize = (15, 15))

mask = np.tril(selected_columns_o.corr())
sns.heatmap(selected_columns_o.corr(), fmt='.1g', annot = True, cmap= 'cool', mask=mask, square=True)

plt.show()
